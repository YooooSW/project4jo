# %%
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib.ticker as mticker
import seaborn as sns
from matplotlib import font_manager, rc # 폰트 세팅을 위한 모듈 추가
font_path = "C:/Windows/Fonts/malgun.ttf" # 사용할 폰트명 경로 삽입
font = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font)

# %%
file_path = "./주요관광지점 입장객20년1월부터20년12월.xlsx"
people_2020 = pd.read_excel(file_path)

# %%
fil1_path = "./주요관광지점 입장객21년1월부터21년12월.xlsx"
people_2021 = pd.read_excel(fil1_path)

# %%
people_2020 =people_2020.dropna()
people_2021 =people_2021.dropna()

# %%
# people_2020.to_excel('20년관광객.xlsx')

# %%
# people_2021.to_excel('21년관광객.xlsx')

# %%
people_2020.head(5)
# Out:
#         시도   군구      관광지 내/외국인  총계(2020.01 ~ 2020.12)      인원계  2020년 01월  \
# 1  제주특별자치도  제주시  국립제주박물관   내국인               173066.0  82044.0    24272.0
# 2  제주특별자치도  제주시  국립제주박물관   외국인                 1339.0    850.0      398.0
# 3  제주특별자치도  제주시  국립제주박물관    합계               174405.0  82894.0    24670.0
# 4  제주특별자치도  제주시    도립미술관   내국인                63223.0  26123.0    11504.0
# 5  제주특별자치도  제주시    도립미술관   외국인                 1871.0   1494.0     1328.0
#
#    2020년 02월  2020년 03월  2020년 04월  2020년 05월  2020년 06월  2020년 07월  \
# 1     8958.0        0.0        0.0     5968.0     6133.0     5726.0
# 2       88.0        0.0        0.0       33.0       28.0       94.0
# 3     9046.0        0.0        0.0     6001.0     6161.0     5820.0
# 4     5424.0        0.0        0.0        0.0      928.0     2232.0
# 5       55.0        0.0        0.0        0.0       25.0       23.0
#
#    2020년 08월  2020년 09월  2020년 10월  2020년 11월  2020년 12월
# ...

# %%
people_2021.head()
# Out:
#         시도   군구      관광지 내/외국인  총계(2021.01 ~ 2021.12)      인원계  2021년 01월  \
# 1  제주특별자치도  제주시  국립제주박물관   내국인               173066.0  91022.0     7235.0
# 2  제주특별자치도  제주시  국립제주박물관   외국인                 1339.0    489.0       14.0
# 3  제주특별자치도  제주시  국립제주박물관    합계               174405.0  91511.0     7249.0
# 4  제주특별자치도  제주시    도립미술관   내국인                63223.0  37100.0      925.0
# 5  제주특별자치도  제주시    도립미술관   외국인                 1871.0    377.0        1.0
#
#    2021년 02월  2021년 03월  2021년 04월  2021년 05월  2021년 06월  2021년 07월  \
# 1     6384.0     3373.0     4772.0     6297.0     6806.0     8967.0
# 2        7.0        5.0       48.0       42.0       55.0       93.0
# 3     6391.0     3378.0     4820.0     6339.0     6861.0     9060.0
# 4     2007.0     2449.0     2597.0     2922.0     2363.0     4534.0
# 5       18.0       11.0       23.0       39.0        9.0       31.0
#
#    2021년 08월  2021년 09월  2021년 10월  2021년 11월  2021년 12월
# ...

# %%
total_2020 = people_2020.loc[people_2020['내/외국인']=='합계']
total_2021 = people_2021.loc[people_2021['내/외국인']=='합계']

# %%
total_2020 = total_2020.reset_index(drop=True)
total_2021 = total_2021.reset_index(drop=True)

# %%
total_2020.head()
# Out:
#         시도   군구       관광지 내/외국인  총계(2020.01 ~ 2020.12)       인원계  2020년 01월  \
# 0  제주특별자치도  제주시   국립제주박물관    합계               174405.0   82894.0    24670.0
# 1  제주특별자치도  제주시     도립미술관    합계                65094.0   27617.0    12832.0
# 2  제주특별자치도  제주시    만장굴관광지    합계               646332.0  310848.0    37506.0
# 3  제주특별자치도  제주시  민속자연사박물관    합계               140613.0   60228.0    22790.0
# 4  제주특별자치도  제주시       비자림    합계              1222341.0  607945.0    49012.0
#
#    2020년 02월  2020년 03월  2020년 04월  2020년 05월  2020년 06월  2020년 07월  \
# 0     9046.0        0.0        0.0     6001.0     6161.0     5820.0
# 1     5479.0        0.0        0.0        0.0      953.0     2255.0
# 2    18882.0    12678.0    10822.0    22405.0    23407.0    35273.0
# 3     6239.0      103.0        0.0        0.0     1742.0     4729.0
# 4    31732.0    31260.0    30457.0    54456.0    57556.0    64278.0
#
#    2020년 08월  2020년 09월  2020년 10월  2020년 11월  2020년 12월
# ...

# %%
total_2021.head()
# Out:
#         시도   군구       관광지 내/외국인  총계(2021.01 ~ 2021.12)       인원계  2021년 01월  \
# 0  제주특별자치도  제주시   국립제주박물관    합계               174405.0   91511.0     7249.0
# 1  제주특별자치도  제주시     도립미술관    합계                65094.0   37477.0      926.0
# 2  제주특별자치도  제주시    만장굴관광지    합계               646332.0  335484.0     7282.0
# 3  제주특별자치도  제주시  민속자연사박물관    합계               140613.0   80385.0     3337.0
# 4  제주특별자치도  제주시       비자림    합계              1222341.0  614396.0    18250.0
#
#    2021년 02월  2021년 03월  2021년 04월  2021년 05월  2021년 06월  2021년 07월  \
# 0     6391.0     3378.0     4820.0     6339.0     6861.0     9060.0
# 1     2025.0     2460.0     2620.0     2961.0     2372.0     4565.0
# 2    12826.0    17903.0    17909.0    30851.0    31024.0    51526.0
# 3     4975.0     6030.0     7646.0     7846.0     5281.0     6653.0
# 4    28841.0    40474.0    40163.0    69626.0    55092.0    62858.0
#
#    2021년 08월  2021년 09월  2021년 10월  2021년 11월  2021년 12월
# ...

# %%
total_2020_1 = total_2020.iloc[0:9]
total_2020_2 = total_2020.iloc[9:18]
total_2020_3 = total_2020.iloc[18:27]
total_2020_4 = total_2020.iloc[27:36]

# %%
total_2021_1 = total_2021.iloc[0:9]
total_2021_2 = total_2021.iloc[9:18]
total_2021_3 = total_2021.iloc[18:27]
total_2021_4 = total_2021.iloc[27:36]

# %%
sns.barplot(x='인원계', y='관광지', data=total_2020_1)
# Out:
# <Axes: xlabel='인원계', ylabel='관광지'>

# %%
total_2020_1
# Out:
#         시도   군구          관광지 내/외국인  총계(2020.01 ~ 2020.12)       인원계  \
# 0  제주특별자치도  제주시      국립제주박물관    합계               174405.0   82894.0
# 1  제주특별자치도  제주시        도립미술관    합계                65094.0   27617.0
# 2  제주특별자치도  제주시       만장굴관광지    합계               646332.0  310848.0
# 3  제주특별자치도  제주시     민속자연사박물관    합계               140613.0   60228.0
# 4  제주특별자치도  제주시          비자림    합계              1222341.0  607945.0
# 5  제주특별자치도  제주시      삼양선사유적지    합계                30934.0   16126.0
# 6  제주특별자치도  제주시      절물자연휴양림    합계              1001539.0  545323.0
# 7  제주특별자치도  제주시  제주도립 김창열미술관    합계                82097.0   21981.0
# 8  제주특별자치도  제주시      제주돌문화공원    합계               171534.0   66896.0
#
#    2020년 01월  2020년 02월  2020년 03월  2020년 04월  2020년 05월  2020년 06월  \
# 0    24670.0     9046.0        0.0        0.0     6001.0     6161.0
# 1    12832.0     5479.0        0.0        0.0        0.0      953.0
# 2    37506.0    18882.0    12678.0    10822.0    22405.0    23407.0
# ...

# %%
total_2021_1
# Out:
#         시도   군구          관광지 내/외국인  총계(2021.01 ~ 2021.12)       인원계  \
# 0  제주특별자치도  제주시      국립제주박물관    합계               174405.0   91511.0
# 1  제주특별자치도  제주시        도립미술관    합계                65094.0   37477.0
# 2  제주특별자치도  제주시       만장굴관광지    합계               646332.0  335484.0
# 3  제주특별자치도  제주시     민속자연사박물관    합계               140613.0   80385.0
# 4  제주특별자치도  제주시          비자림    합계              1222341.0  614396.0
# 5  제주특별자치도  제주시      삼양선사유적지    합계                30934.0   14808.0
# 6  제주특별자치도  제주시      절물자연휴양림    합계              1001539.0  456216.0
# 7  제주특별자치도  제주시  제주도립 김창열미술관    합계                82097.0   60116.0
# 8  제주특별자치도  제주시      제주돌문화공원    합계               171534.0  104638.0
#
#    2021년 01월  2021년 02월  2021년 03월  2021년 04월  2021년 05월  2021년 06월  \
# 0     7249.0     6391.0     3378.0     4820.0     6339.0     6861.0
# 1      926.0     2025.0     2460.0     2620.0     2961.0     2372.0
# 2     7282.0    12826.0    17903.0    17909.0    30851.0    31024.0
# ...

# %%
sns.barplot(x='인원계', y='관광지', data=total_2020)
# Out:
# <Axes: xlabel='인원계', ylabel='관광지'>

# %%
sns.barplot(x='인원계', y='관광지', data=total_2021)
# Out:
# <Axes: xlabel='인원계', ylabel='관광지'>

# %%
# 2020년 여행객 총합
plt.figure(figsize=(15, 12))

plt.subplot(221)
plt.bar(total_2020_1['관광지'], total_2020_1['인원계'])
plt.title('1~10')
plt.xticks(rotation=90, fontsize=10)
plt.ylim([0, 900000])
plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f만'))

plt.subplot(222)
plt.bar(total_2020_2['관광지'], total_2020_2['인원계'])
plt.title('11~20')
plt.xticks(rotation=90, fontsize=10)
plt.ylim([0, 900000])
plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f만'))

plt.subplot(223)
plt.bar(total_2020_3['관광지'], total_2020_3['인원계'])
plt.title('21~30')
plt.xticks(rotation=90, fontsize=10)
plt.ylim([0, 900000])
plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f만'))

plt.subplot(224)
plt.bar(total_2020_4['관광지'], total_2020_4['인원계'])
plt.title('31~36')
plt.xticks(rotation=90, fontsize=10)
plt.ylim([0, 900000])
plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f만'))

# subplot 간 간격 조절
plt.subplots_adjust(wspace=0.5, hspace=0.5)

plt.show()

# %%
# 2021년 여행객 총합
plt.figure(figsize=(15, 12))

plt.subplot(221)
plt.bar(total_2021_1['관광지'], total_2021_1['인원계'])
plt.title('1~10')
plt.xticks(rotation=90, fontsize=10)
plt.ylim([0, 900000])
plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f만'))

plt.subplot(222)
plt.bar(total_2021_2['관광지'], total_2021_2['인원계'])
plt.title('11~20')
plt.xticks(rotation=90, fontsize=10)
plt.ylim([0, 900000])
plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f만'))

plt.subplot(223)
plt.bar(total_2021_3['관광지'], total_2021_3['인원계'])
plt.title('21~30')
plt.xticks(rotation=90, fontsize=10)
plt.ylim([0, 900000])
plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f만'))

plt.subplot(224)
plt.bar(total_2021_4['관광지'], total_2021_4['인원계'])
plt.title('31~36')
plt.xticks(rotation=90, fontsize=10)
plt.ylim([0, 900000])
plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f만'))

# subplot 간 간격 조절
plt.subplots_adjust(wspace=0.5, hspace=0.5)

plt.show()

# %%
# people_2020.rename(columns={'총계(2020.01 ~ 2020.12)':'20년총계'}, inplace=True)
# people_2020
# Out:
#           시도    군구         관광지 내/외국인      20년총계       인원계  2020년 01월  \
# 1    제주특별자치도   제주시     국립제주박물관   내국인   173066.0   82044.0    24272.0
# 2    제주특별자치도   제주시     국립제주박물관   외국인     1339.0     850.0      398.0
# 3    제주특별자치도   제주시     국립제주박물관    합계   174405.0   82894.0    24670.0
# 4    제주특별자치도   제주시       도립미술관   내국인    63223.0   26123.0    11504.0
# 5    제주특별자치도   제주시       도립미술관   외국인     1871.0    1494.0     1328.0
# ..       ...   ...         ...   ...        ...       ...        ...
# 104  제주특별자치도  서귀포시       퍼시픽랜드   외국인        0.0       0.0        0.0
# 105  제주특별자치도  서귀포시       퍼시픽랜드    합계   233601.0  110174.0    22429.0
# 106  제주특별자치도  서귀포시  한화아쿠아플라넷제주   내국인  1118429.0  443699.0    60309.0
# 107  제주특별자치도  서귀포시  한화아쿠아플라넷제주   외국인    12428.0   11520.0     7542.0
# 108  제주특별자치도  서귀포시  한화아쿠아플라넷제주    합계  1130857.0  455219.0    67851.0
#
#      2020년 02월  2020년 03월  2020년 04월  2020년 05월  2020년 06월  2020년 07월  \
# ...

# %%
# 제주시 여행객 합계
total_visitors1 = people_2020[people_2020['군구'] == '제주시']
total_visitors1
# Out:
#          시도   군구          관광지 내/외국인      20년총계       인원계  2020년 01월  \
# 1   제주특별자치도  제주시      국립제주박물관   내국인   173066.0   82044.0    24272.0
# 2   제주특별자치도  제주시      국립제주박물관   외국인     1339.0     850.0      398.0
# 3   제주특별자치도  제주시      국립제주박물관    합계   174405.0   82894.0    24670.0
# 4   제주특별자치도  제주시        도립미술관   내국인    63223.0   26123.0    11504.0
# 5   제주특별자치도  제주시        도립미술관   외국인     1871.0    1494.0     1328.0
# 6   제주특별자치도  제주시        도립미술관    합계    65094.0   27617.0    12832.0
# 7   제주특별자치도  제주시       만장굴관광지   내국인   628882.0  300484.0    34978.0
# 8   제주특별자치도  제주시       만장굴관광지   외국인    17450.0   10364.0     2528.0
# 9   제주특별자치도  제주시       만장굴관광지    합계   646332.0  310848.0    37506.0
# 10  제주특별자치도  제주시     민속자연사박물관   내국인   130641.0   50584.0    14790.0
# 11  제주특별자치도  제주시     민속자연사박물관   외국인     9972.0    9644.0     8000.0
# 12  제주특별자치도  제주시     민속자연사박물관    합계   140613.0   60228.0    22790.0
# 13  제주특별자치도  제주시          비자림   내국인  1221277.0  607384.0    48890.0
# ...

# %%
total_visitors1['20년총계'].sum()
# Out:
# 10983382.0

# %%
people_2021.rename(columns={'총계(2021.01 ~ 2021.12)':'21년총계'}, inplace=True)
people_2021
# Out:
#           시도    군구         관광지 내/외국인      21년총계       인원계  2021년 01월  \
# 1    제주특별자치도   제주시     국립제주박물관   내국인   173066.0   91022.0     7235.0
# 2    제주특별자치도   제주시     국립제주박물관   외국인     1339.0     489.0       14.0
# 3    제주특별자치도   제주시     국립제주박물관    합계   174405.0   91511.0     7249.0
# 4    제주특별자치도   제주시       도립미술관   내국인    63223.0   37100.0      925.0
# 5    제주특별자치도   제주시       도립미술관   외국인     1871.0     377.0        1.0
# ..       ...   ...         ...   ...        ...       ...        ...
# 104  제주특별자치도  서귀포시       퍼시픽랜드   외국인        0.0       0.0        0.0
# 105  제주특별자치도  서귀포시       퍼시픽랜드    합계   233601.0  123427.0     3547.0
# 106  제주특별자치도  서귀포시  한화아쿠아플라넷제주   내국인  1118429.0  674730.0    20314.0
# 107  제주특별자치도  서귀포시  한화아쿠아플라넷제주   외국인    12428.0     908.0       10.0
# 108  제주특별자치도  서귀포시  한화아쿠아플라넷제주    합계  1130857.0  675638.0    20324.0
#
#      2021년 02월  2021년 03월  2021년 04월  2021년 05월  2021년 06월  2021년 07월  \
# ...

# %%
# 제주시 여행객 합계
total_visitors3 = people_2021[people_2021['군구'] == '제주시']
total_visitors3
# 서귀포시 여행객 합계
total_visitors4 = people_2021[people_2021['군구'] == '서귀포시']
total_visitors4
# Out:
#           시도    군구          관광지 내/외국인      21년총계       인원계  2021년 01월  \
# 49   제주특별자치도  서귀포시        감귤박물관   내국인    82336.0   48654.0     1580.0
# 50   제주특별자치도  서귀포시        감귤박물관   외국인       92.0      61.0        0.0
# 51   제주특별자치도  서귀포시        감귤박물관    합계    82428.0   48715.0     1580.0
# 52   제주특별자치도  서귀포시        기당미술관   내국인    20179.0   12955.0      767.0
# 53   제주특별자치도  서귀포시        기당미술관   외국인        8.0       2.0        0.0
# 54   제주특별자치도  서귀포시        기당미술관    합계    20187.0   12957.0      767.0
# 55   제주특별자치도  서귀포시     마라해양도립공원   내국인  1116994.0  635253.0    13018.0
# 56   제주특별자치도  서귀포시     마라해양도립공원   외국인        0.0       0.0        0.0
# 57   제주특별자치도  서귀포시     마라해양도립공원    합계  1116994.0  635253.0    13018.0
# 58   제주특별자치도  서귀포시     박물관은살아있다   내국인   309855.0  151580.0     5712.0
# 59   제주특별자치도  서귀포시     박물관은살아있다   외국인     3093.0      30.0        6.0
# 60   제주특별자치도  서귀포시     박물관은살아있다    합계   312948.0  151610.0     5718.0
# ...

# %%
# 서귀포시 여행객 합계
total_visitors2 = people_2020[people_2020['군구'] == '서귀포시']
total_visitors2
# Out:
#           시도    군구          관광지 내/외국인      20년총계       인원계  2020년 01월  \
# 49   제주특별자치도  서귀포시        감귤박물관   내국인    82336.0   33682.0    16525.0
# 50   제주특별자치도  서귀포시        감귤박물관   외국인       92.0      31.0       15.0
# 51   제주특별자치도  서귀포시        감귤박물관    합계    82428.0   33713.0    16540.0
# 52   제주특별자치도  서귀포시        기당미술관   내국인    20179.0    7224.0     1866.0
# 53   제주특별자치도  서귀포시        기당미술관   외국인        8.0       6.0        1.0
# 54   제주특별자치도  서귀포시        기당미술관    합계    20187.0    7230.0     1867.0
# 55   제주특별자치도  서귀포시     마라해양도립공원   내국인  1116994.0  481741.0    49115.0
# 56   제주특별자치도  서귀포시     마라해양도립공원   외국인        0.0       0.0        0.0
# 57   제주특별자치도  서귀포시     마라해양도립공원    합계  1116994.0  481741.0    49115.0
# 58   제주특별자치도  서귀포시     박물관은살아있다   내국인   309855.0  158275.0    33965.0
# 59   제주특별자치도  서귀포시     박물관은살아있다   외국인     3093.0    3063.0     2276.0
# 60   제주특별자치도  서귀포시     박물관은살아있다    합계   312948.0  161338.0    36241.0
# ...

# %%
total_visitors2['20년총계'].sum()
# Out:
# 21310164.0

# %%
import re

new_cols = {}
for col in total_visitors1.columns:
    if col.startswith('2020년 '):
        new_cols[col] = col.replace('2020년 ', '2020-')
total_visitors1 = total_visitors1.rename(columns=new_cols)

total_visitors1.columns = total_visitors1.columns.str.replace('월', '')
total_visitors1.columns = total_visitors1.columns.str.replace('(?<=\d{2})년 ', '-', regex=True)
total_visitors1.columns

total_visitors1.columns
# Out:
# Index(['시도', '군구', '관광지', '내/외국인', '20년총계', '인원계', '2020-01', '2020-02',
#        '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08',
#        '2020-09', '2020-10', '2020-11', '2020-12'],
#       dtype='object')

# %%
import re

new_cols = {}
for col in total_visitors2.columns:
    if col.startswith('2020년 '):
        new_cols[col] = col.replace('2020년 ', '2020-')
total_visitors2 = total_visitors2.rename(columns=new_cols)

total_visitors2.columns = total_visitors2.columns.str.replace('월', '')
total_visitors2.columns = total_visitors2.columns.str.replace('(?<=\d{2})년 ', '-', regex=True)
total_visitors2.columns

total_visitors2.columns
# Out:
# Index(['시도', '군구', '관광지', '내/외국인', '20년총계', '인원계', '2020-01', '2020-02',
#        '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08',
#        '2020-09', '2020-10', '2020-11', '2020-12'],
#       dtype='object')

# %%
total_visitors1
# Out:
#          시도   군구          관광지 내/외국인      20년총계       인원계   2020-01  2020-02  \
# 1   제주특별자치도  제주시      국립제주박물관   내국인   173066.0   82044.0   24272.0   8958.0
# 2   제주특별자치도  제주시      국립제주박물관   외국인     1339.0     850.0     398.0     88.0
# 3   제주특별자치도  제주시      국립제주박물관    합계   174405.0   82894.0   24670.0   9046.0
# 4   제주특별자치도  제주시        도립미술관   내국인    63223.0   26123.0   11504.0   5424.0
# 5   제주특별자치도  제주시        도립미술관   외국인     1871.0    1494.0    1328.0     55.0
# 6   제주특별자치도  제주시        도립미술관    합계    65094.0   27617.0   12832.0   5479.0
# 7   제주특별자치도  제주시       만장굴관광지   내국인   628882.0  300484.0   34978.0  17328.0
# 8   제주특별자치도  제주시       만장굴관광지   외국인    17450.0   10364.0    2528.0   1554.0
# 9   제주특별자치도  제주시       만장굴관광지    합계   646332.0  310848.0   37506.0  18882.0
# 10  제주특별자치도  제주시     민속자연사박물관   내국인   130641.0   50584.0   14790.0   4735.0
# 11  제주특별자치도  제주시     민속자연사박물관   외국인     9972.0    9644.0    8000.0   1504.0
# ...

# %%
tourlist2020 = pd.concat([total_visitors1, total_visitors2], axis=0)
tourlist2020
# Out:
#           시도    군구         관광지 내/외국인      20년총계       인원계  2020-01  2020-02  \
# 1    제주특별자치도   제주시     국립제주박물관   내국인   173066.0   82044.0  24272.0   8958.0
# 2    제주특별자치도   제주시     국립제주박물관   외국인     1339.0     850.0    398.0     88.0
# 3    제주특별자치도   제주시     국립제주박물관    합계   174405.0   82894.0  24670.0   9046.0
# 4    제주특별자치도   제주시       도립미술관   내국인    63223.0   26123.0  11504.0   5424.0
# 5    제주특별자치도   제주시       도립미술관   외국인     1871.0    1494.0   1328.0     55.0
# ..       ...   ...         ...   ...        ...       ...      ...      ...
# 104  제주특별자치도  서귀포시       퍼시픽랜드   외국인        0.0       0.0      0.0      0.0
# 105  제주특별자치도  서귀포시       퍼시픽랜드    합계   233601.0  110174.0  22429.0   5416.0
# 106  제주특별자치도  서귀포시  한화아쿠아플라넷제주   내국인  1118429.0  443699.0  60309.0  18888.0
# 107  제주특별자치도  서귀포시  한화아쿠아플라넷제주   외국인    12428.0   11520.0   7542.0   2877.0
# 108  제주특별자치도  서귀포시  한화아쿠아플라넷제주    합계  1130857.0  455219.0  67851.0  21765.0
#
# ...

# %%
import re

new_cols = {}
for col in total_visitors3.columns:
    if col.startswith('2021년 '):
        new_cols[col] = col.replace('2021년 ', '2021-')
total_visitors3 = total_visitors3.rename(columns=new_cols)

total_visitors3.columns = total_visitors3.columns.str.replace('월', '')
total_visitors3.columns = total_visitors3.columns.str.replace('(?<=\d{2})년 ', '-', regex=True)
total_visitors3.columns

total_visitors3.columns
# Out:
# Index(['시도', '군구', '관광지', '내/외국인', '21년총계', '인원계', '2021-01', '2021-02',
#        '2021-03', '2021-04', '2021-05', '2021-06', '2021-07', '2021-08',
#        '2021-09', '2021-10', '2021-11', '2021-12'],
#       dtype='object')

# %%
import re

new_cols = {}
for col in total_visitors4.columns:
    if col.startswith('2021년 '):
        new_cols[col] = col.replace('2021년 ', '2021-')
total_visitors4 = total_visitors4.rename(columns=new_cols)

total_visitors4.columns = total_visitors4.columns.str.replace('월', '')
total_visitors4.columns = total_visitors4.columns.str.replace('(?<=\d{2})년 ', '-', regex=True)
total_visitors4.columns

total_visitors4.columns
# Out:
# Index(['시도', '군구', '관광지', '내/외국인', '21년총계', '인원계', '2021-01', '2021-02',
#        '2021-03', '2021-04', '2021-05', '2021-06', '2021-07', '2021-08',
#        '2021-09', '2021-10', '2021-11', '2021-12'],
#       dtype='object')

# %%
tourlist2021 = pd.concat([total_visitors3, total_visitors4], axis=0)
tourlist2021
# Out:
#           시도    군구         관광지 내/외국인      21년총계       인원계  2021-01  2021-02  \
# 1    제주특별자치도   제주시     국립제주박물관   내국인   173066.0   91022.0   7235.0   6384.0
# 2    제주특별자치도   제주시     국립제주박물관   외국인     1339.0     489.0     14.0      7.0
# 3    제주특별자치도   제주시     국립제주박물관    합계   174405.0   91511.0   7249.0   6391.0
# 4    제주특별자치도   제주시       도립미술관   내국인    63223.0   37100.0    925.0   2007.0
# 5    제주특별자치도   제주시       도립미술관   외국인     1871.0     377.0      1.0     18.0
# ..       ...   ...         ...   ...        ...       ...      ...      ...
# 104  제주특별자치도  서귀포시       퍼시픽랜드   외국인        0.0       0.0      0.0      0.0
# 105  제주특별자치도  서귀포시       퍼시픽랜드    합계   233601.0  123427.0   3547.0   8133.0
# 106  제주특별자치도  서귀포시  한화아쿠아플라넷제주   내국인  1118429.0  674730.0  20314.0  46618.0
# 107  제주특별자치도  서귀포시  한화아쿠아플라넷제주   외국인    12428.0     908.0     10.0     54.0
# 108  제주특별자치도  서귀포시  한화아쿠아플라넷제주    합계  1130857.0  675638.0  20324.0  46672.0
#
# ...

# %%
# tourlist2020.to_excel('2020년제주여행객마지막.xlsx')

# %%
# tourlist2021.to_excel('2021년제주여행객마지막.xlsx')
